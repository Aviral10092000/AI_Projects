# %%
from bs4 import BeautifulSoup, SoupStrainer
from selenium import webdriver
import time

# Initialize WebDriver
driver = webdriver.Chrome()  # You should replace this with the appropriate web driver you're using (Chrome, Firefox, etc.)

# Open the URL of the webpage
url = "https://in.pinterest.com/search/pins/?q=night&rs=typed"
driver.get(url)

# Automatically scroll the page
scroll_pause_time = 2  # Pause between each scroll
screen_height = driver.execute_script("return window.screen.height;")  # Browser window height
i = 1
while True:
    # Scroll down
    driver.execute_script(f"window.scrollTo(0, {screen_height * i});")
    i += 1
    time.sleep(scroll_pause_time)
    for link in BeautifulSoup(driver.page_source, 'html.parser', parse_only=SoupStrainer('img')):
        if link.has_attr('src'):
            if "/60x60/" not in link['src']:
                
    # Check if reaching the end of the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")
    if screen_height * i > scroll_height:
        break

# Fetch the data using BeautifulSoup after all data is loaded
# Process and save the data as needed

# Close the WebDriver session
driver.quit()
# Out:
# https://i.pinimg.com/60x60/03/d5/47/03d547b605b4c0857dcf78b5474f9d86.jpg
# https://i.pinimg.com/60x60/c5/84/c5/c584c54059c5b7341a21aa3e8dd19d0e.jpg
# https://i.pinimg.com/60x60/5d/80/fa/5d80fa71327ead21ae87a09b872e572d.jpg
# https://i.pinimg.com/60x60/75/fe/cd/75fecd843d25c557f480f893cbef4b6b.jpg
# https://i.pinimg.com/60x60/29/c2/92/29c292e800184b6abd290c9c1e276149.jpg
# https://i.pinimg.com/60x60/96/8f/60/968f608f774a50f1cacbe5f7708685bd.jpg
# https://i.pinimg.com/60x60/0e/95/4e/0e954eb56aa64bcfa99c97c5a2dcb84d.jpg
# https://i.pinimg.com/60x60/75/fe/cd/75fecd843d25c557f480f893cbef4b6b.jpg
# https://i.pinimg.com/60x60/7e/db/6c/7edb6c9378a96dc36315fa64a6e58668.jpg
# https://i.pinimg.com/60x60/82/39/4e/82394ea3ba3f385302b70f7ab0aaef38.jpg
# https://i.pinimg.com/60x60/85/9f/5f/859f5fe5a00ba2303c73ca6b7709de26.jpg
# https://i.pinimg.com/60x60/57/f5/a8/57f5a8e327aae05154cd6df38fac3b5a.jpg
# https://i.pinimg.com/60x60/99/bd/24/99bd24b1212d3dbe50918fb9b5dc4cb0.jpg
# https://i.pinimg.com/60x60/01/69/6b/01696be7b0553fb35c12d6d1b59e664b.jpg
# https://i.pinimg.com/60x60/0b/0d/4c/0b0d4ccca6da611b757f5172136e8746.jpg
# https://i.pinimg.com/60x60/d5/b1/0f/d5b10ff90efb68a958598c700dd2ff52.jpg
# https://i.pinimg.com/60x60/97/9c/41/979c417b5cdc67e890c73837c7c42a81.jpg
# https://i.pinimg.com/60x60/43/b8/a9/43b8a954a3538fbfde588d879306d091.jpg
# https://i.pinimg.com/60x60/79/ed/45/79ed45a83f2cd9dcb606b4b05df73181.jpg
# https://i.pinimg.com/60x60/c9/25/87/c92587835a62f3833212738b1680ef83.jpg
# https://i.pinimg.com/60x60/1d/b8/ec/1db8ec26d5da93337e5834e41b6e6bc2.jpg
# https://i.pinimg.com/60x60/c9/db/3d/c9db3d489a75fb8ccc6983fc3f281405.jpg
# https://i.pinimg.com/60x60/bf/00/25/bf0025b1dd4faabff3666e783322f4d9.jpg
# https://i.pinimg.com/60x60/07/ee/e2/07eee20a3b896a7f9f03ae8a1e4b2b75.jpg
# https://i.pinimg.com/60x60/79/ed/45/79ed45a83f2cd9dcb606b4b05df73181.jpg
# https://i.pinimg.com/236x/c5/d7/46/c5d7462a672e07ee74f81ef1a5ee518a.jpg
# https://i.pinimg.com/236x/a0/07/12/a007122f9790a6d587189b39fe17785a.jpg
# https://i.pinimg.com/236x/08/98/44/089844bdc0cfee7070a63fecb0dc5774.jpg
# https://i.pinimg.com/236x/01/a1/8b/01a18baf2f74c3289eb8fd5de4a95ae9.jpg
# https://i.pinimg.com/236x/00/6a/9d/006a9dd3baabdf50202c4cbc556344cd.jpg
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[18], line 21
#      19 i += 1
#      20 time.sleep(scroll_pause_time)
# ---> 21 for link in BeautifulSoup(driver.page_source, 'html.parser', parse_only=SoupStrainer('img')):
#      22     if link.has_attr('src'):
#      23         print(link['src'])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:570, in WebDriver.page_source(self)
#     562 @property
#     563 def page_source(self) -> str:
#     564     """Gets the source of the current page.
#     565
#     566     Example:
#     567     --------
#     568     >>> print(driver.page_source)
#     569     """
# --> 570     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF68DF680D5+2992373]
# 	(No symbol) [0x00007FF68DBFBFD0]
# 	(No symbol) [0x00007FF68DA9590A]
# 	(No symbol) [0x00007FF68DA6F4F5]
# 	(No symbol) [0x00007FF68DB163A7]
# 	(No symbol) [0x00007FF68DB2EE72]
# 	(No symbol) [0x00007FF68DB0F113]
# 	(No symbol) [0x00007FF68DADA918]
# 	(No symbol) [0x00007FF68DADBA81]
# 	GetHandleVerifier [0x00007FF68DFC6A2D+3379789]
# 	GetHandleVerifier [0x00007FF68DFDC32D+3468109]
# 	GetHandleVerifier [0x00007FF68DFD0043+3418211]
# 	GetHandleVerifier [0x00007FF68DD5C78B+847787]
# 	(No symbol) [0x00007FF68DC0757F]
# 	(No symbol) [0x00007FF68DC02FC4]
# 	(No symbol) [0x00007FF68DC0315D]
# 	(No symbol) [0x00007FF68DBF2979]
# 	BaseThreadInitThunk [0x00007FFD9C12259D+29]
# 	RtlUserThreadStart [0x00007FFD9DB4AF38+40]
