# %%
import openai
import os

# %%
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
OPENAI_API_KEY
# Out:
# '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'

# %%
def get_response(messages,model):
    
    response = openai.chat.completions.create(
        model=model,
        messages=messages)
    
    return response.choices[0].message.content

# %%
model=["gpt-4o-mini", "gpt-4o"]

# %%
system_role = "You are a helpful assistant that answers multiple choice questions about medical knowledge."

# %%
first_question= '''A 4670-g (10-lb 5-oz) male newborn is delivered at term to a 26-year-old woman after prolonged labor. Apgar scores are 9 and 9 at 1 and 5 minutes. Examination in the delivery room shows swelling, tenderness, and crepitus over the left clavicle. There is decreased movement of the left upper extremity. Movement of the hands and wrists are normal. A grasping reflex is normal in both hands. An asymmetric Moro reflex is present. The remainder of the examination shows no abnormalities and an anteroposterior x-ray confirms the diagnosis. Which of the following is the most appropriate next step in management?
(A)Nerve conduction study
(B)Surgical fixation
(C)Physical therapy
(D)Pin sleeve to the shirt
(E)Splinting of the arm
(F)MRI of the clavicle
'''

# %%
first_question_answer= 'D'

# %%
second_question='''A 40-year-old man comes to the physician because of a 5-month history of watery diarrhea and episodic crampy abdominal pain. He has no fever, nausea, or vomiting. Over the past 6 months, he has had a 1.8-kg (4-lb) weight loss, despite experiencing no decrease in appetite. His wife has noticed that sometimes his face and neck become red after meals or when he is in distress. A year ago, he was diagnosed with asthma. He has hypertension. Current medications include an albuterol inhaler and enalapril. He drinks one beer daily. His temperature is 36.7°C (98°F), pulse is 85/min, and blood pressure is 130/85 mm Hg. The lungs are clear to auscultation. A grade 2/6 systolic murmur is heard best at the left sternal border and fourth intercostal space. The abdomen is soft, and there is mild tenderness to palpation with no guarding or rebound. The remainder of the physical examination shows no abnormalities. A complete blood count is within the reference range. Without treatment, this patient is at greatest risk for which of the following conditions?
(A)Asphyxia
(B)Achlorhydria
(C)T-cell lymphoma
(D)Megaloblastic anemia
(E)Dementia
(F)Intestinal fistula
(G)Arthritis
'''

# %%
second_question_answer='E'

# %%
third_question='''哪项是含维生素泛酸的辅酶？（　　）
(A)NAD
(B)HS-CoA
(C)磷酸吡哆醛
(D)TPP
(E)FAD
'''

# %%
third_question_answer='B'

# %%
fourth_question='''下列何者位於後縱隔？
(A)心臟
(B)胸主動脈
(C)下腔靜脈
(D)氣管
'''

# %%
#Few shot prompting

# %%
user_prompt = f'''Question:{first_question}
Answer:{first_question_answer}

Question:{second_question}
Answer:{second_question_answer}

Question:{third_question}
Answer:{third_question_answer}

Question:{fourth_question}
Answer:
'''

# %%
messages=[{'role':'system','content':system_role},
          {'role':'user','content':user_prompt}
          ]

# %%
for m in model:
    print(get_response(messages, m))
# Out:
# (B)胸主動脈
# The most appropriate answer for the structure located in the posterior mediastinum is:
#
# (B)胸主動脈 (Thoracic aorta)

# %%
#One shot prompting

# %%
user_prompt = f'''Question:{first_question}
Answer:{first_question_answer}

Question:{fourth_question}
Answer:
'''

# %%
messages=[{'role':'system','content':system_role},
          {'role':'user','content':user_prompt}
          ]

# %%
for m in model:
    print(get_response(messages, m))
# Out:
# 在後縱隔的位置上，正確的答案是：
#
# (B)胸主動脈
#
# 後縱隔包含胸主動脈、食道、氣管的延續、以及胸膜的部分。因此，胸主動脈是位於後縱隔的結構之一。
# Question 1: The patient has a fractured clavicle, which is common in newborns after difficult deliveries. The most appropriate next step in management is to support the affected arm to prevent movement and pain. By pinning the sleeve to the shirt, you immobilize the arm lightly and allow the fracture to heal naturally. Therefore, the correct answer is (D) Pin sleeve to the shirt.
#
# Question 2: Within the posterior mediastinum, the thoracic aorta can be found. Structures like the heart are located in the middle mediastinum, while the inferior vena cava isn't typically described as being in the posterior mediastinum, and the trachea is in the superior mediastinum. Therefore, the correct answer is (B) 胸主動脈 (Thoracic aorta).

# %%
#Zero shot prompting

# %%
user_prompt = f'''Question:{fourth_question}
Answer:
'''

# %%
messages=[{'role':'system','content':system_role},
          {'role':'user','content':user_prompt}
          ]

# %%
for m in model:
    print(get_response(messages, m))
# Out:
# 答案是 (B) 胸主動脈。
#
# 後縱隔主要包括胸主動脈、食道、胸管以及某些神經和淋巴結等結構。心臟位於前縱隔，而氣管則位於中縱隔。下腔靜脈通常是在腹腔內。因此，胸主動脈是正確的選擇。
# 下列選項中，位於後縱隔的是：
#
# (B)胸主動脈
#
# 後縱隔是位於心臟後方的一個區域，主要包含胸主動脈、胸椎、食道等結構。
